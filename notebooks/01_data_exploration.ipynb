# %% [markdown]
# ### download the dataset from kagel:

# %%
# !pip install -q Kaggle
# !pip install --upgrade kaggle
# Out:
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kaggle in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (2.2.4)
# Requirement already satisfied: bleach in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: jupytext in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (1.19.5)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.35 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (0.1.37)
# Requirement already satisfied: packaging in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (25.0)
# Requirement already satisfied: protobuf in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (7.34.1)
# Requirement already satisfied: python-dateutil in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (1.1.1)
# Requirement already satisfied: python-slugify in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (2.32.4)
# Requirement already satisfied: tqdm in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from kaggle) (1.26.20)
# Requirement already satisfied: webencodings in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from jupytext->kaggle) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from jupytext->kaggle) (0.6.1)
# Requirement already satisfied: nbformat in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from jupytext->kaggle) (6.0.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from markdown-it-py>=1.0->jupytext->kaggle) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from nbformat->jupytext->kaggle) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from nbformat->jupytext->kaggle) (4.24.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from nbformat->jupytext->kaggle) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from nbformat->jupytext->kaggle) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.3.8)
# Requirement already satisfied: pywin32>=300 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (310)
# Requirement already satisfied: six>=1.5 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from requests->kaggle) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from requests->kaggle) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from requests->kaggle) (2025.7.14)
# Requirement already satisfied: colorama in C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages (from tqdm->kaggle) (0.4.6)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (C:\Users\Mohamed\AppData\Roaming\Python\Python313\site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Download the datasets

# %%
import os
from dotenv import load_dotenv

# Load variables from .env file (located one folder up)
load_dotenv(dotenv_path="../.env")

# Set the token for Kaggle
os.environ["KAGGLE_API_TOKEN"] = os.getenv("KAGGLE_API_TOKEN")

# Download the dataset and unzip it directly into the 'data' folder
print("Downloading dataset...")
# !kaggle datasets download -d anvitkumar/shopping-dataset -p ../data --unzip
print("Dataset downloaded to the 'data' folder successfully ✅")
# Out:
# Downloading dataset...
# Dataset URL: https://www.kaggle.com/datasets/anvitkumar/shopping-dataset
# License(s): MIT
# Downloading shopping-dataset.zip to ../data
#
# Dataset downloaded to the 'data' folder successfully ✅
#   0%|          | 0.00/1.22M [00:00<?, ?B/s]
#  82%|████████▏ | 1.00M/1.22M [00:00<00:00, 1.58MB/s]
# 100%|██████████| 1.22M/1.22M [00:00<00:00, 1.73MB/s]

# %% [markdown]
# ## loading the dataset

# %%
import pandas as pd

# Load the combined dataset
df = pd.read_csv("../data/Combined_dataset.csv")

# Print shape
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (1000, 24)

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
# 2  http://assets.myntassets.com/assets/images/176...  ...
# 3  http://assets.myntassets.com/assets/images/137...  ...
# 4  http://assets.myntassets.com/assets/images/pro...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
# 1  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
# 2  {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...                 NaN
# 3  {"1_star":33,"2_stars":21,"3_stars":69,"4_star...                 NaN
# 4  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
#
#   seller_name                                              sizes  \
# 0         NaN                               [{"size":"Onesize"}]
# 1         NaN                               [{"size":"Onesize"}]
# 2         NaN                                     [{"size":"S"}]
# 3         NaN                               [{"size":"Onesize"}]
# 4         NaN  [{"size":"M","value":"45.0in","value_name":"Fr...
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                NaN
# 1                              ["rw-9136281_cae700"]                NaN
# 2  ["https://videos.myntassets.com/assets/videos/...                NaN
# 3  ["https://videos.myntassets.com/assets/videos/...                NaN
# 4                                                NaN                NaN
#
#                                     variations best_offer  \
# 0                                         [{}]         {}
# 1                                      [{},{}]         {}
# 2                          [{},{},{},{},{},{}]         {}
# 3                                          NaN         {}
# 4  [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                          more_offers   category
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 3  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 4  [{"offer_name":"10% Instant Discount on IndusI...  bath-robe
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   object
#  2   product_description     1000 non-null   object
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   object
#  8   currency                1000 non-null   object
#  9   images                  1000 non-null   object
#  10  delivery_options        1000 non-null   object
#  11  product_details         1000 non-null   object
#  12  breadcrumbs             1000 non-null   object
#  13  product_specifications  1000 non-null   object
#  14  amount_of_stars         1000 non-null   object
#  15  what_customers_said     427 non-null    object
#  16  seller_name             699 non-null    object
#  17  sizes                   1000 non-null   object
#  18  videos                  219 non-null    object
#  19  seller_information      699 non-null    object
#  20  variations              438 non-null    object
#  21  best_offer              1000 non-null   object
#  22  more_offers             1000 non-null   object
#  23  category                1000 non-null   object
# dtypes: float64(2), int64(3), object(19)
# memory usage: 187.6+ KB

# %% [markdown]
# > ### Notes this:
#  - we here find the 'final_price' is in (object) format not in (float) format.

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# discount               121
# what_customers_said    573
# seller_name            301
# videos                 781
# seller_information     301
# variations             562
# dtype: int64

# %% [markdown]
# we found there is missing data in [`discount`, `what_customers_said`, `seller_name`, `videos`, `seller_information`, `variations`].
#  - and they are not that important like the others

# %% [markdown]
# ###  Check missing values for the columns we care about

# %%
columns_that_matters = ['title', 'product_description', 'rating', 'initial_price', 'final_price', 'currency']
print("\nMissing values count:")
print(df[columns_that_matters].isnull().sum())

# Display the first 2 rows
df[columns_that_matters].head(2)
# Out:
# Missing values count:
# title                  0
# product_description    0
# rating                 0
# initial_price          0
# final_price            0
# currency               0
# dtype: int64
#             title                product_description  rating  initial_price  \
# 0     Lino Perros     Women Navy Blue Solid Backpack     3.8           3995
# 1  Tommy Hilfiger  Unisex Navy Blue Striped Backpack     4.5           2899
#
#    final_price currency
# 0  "₹3,995.00"      INR
# 1  "₹2,899.00"      INR

# %% [markdown]
# > ### Notes again :
#  - we here find the 'final_price' also contains the Indian Rupee symbol "₹3,995.00" and commas, so it needs to be cleaned up and converted to dollars & convert it into 'float'.

# %% [markdown]
# ### Defect 1: Clean and convert prices to USD

# %%
import re

def clean_and_convert_price(price_str, currency):
    price_str = str(price_str).strip()
    # Remove everything except digits and dot
    price_clean = re.sub(r'[^\d.]', '', price_str)
    price_val = float(price_clean) if price_clean else 0.0
    
    # Convert INR (₹) to USD (1 INR ~ 0.012 USD)
    if 'INR' in str(currency) or '₹' in price_str:
        price_val = price_val * 0.012
        
    return round(price_val, 2)

# %%
df['final_price_usd'] = df.apply(lambda row: clean_and_convert_price(row['final_price'], row['currency']), axis=1)
df['initial_price_usd'] = df.apply(lambda row: clean_and_convert_price(row['initial_price'], row['currency']), axis=1)

# %% [markdown]
# ##### Show Before & After for "**prices**"

# %%
print("--- Price Cleaning Check ---")
print("Before:", df['final_price'].head(3).tolist())
print("After (USD):", df['final_price_usd'].head(3).tolist())
# Out:
# --- Price Cleaning Check ---
# Before: ['"₹3,995.00"', '"₹2,899.00"', '"₹2,999.00"']
# After (USD): [47.94, 34.79, 35.99]

# %% [markdown]
# ### Defect 2: Handle specific missing values without dropping rows

# %%
df['what_customers_said'] = df['what_customers_said'].fillna('No reviews available')
df['seller_name'] = df['seller_name'].fillna('Unknown Seller')
df['variations'] = df['variations'].fillna('Standard')
df['images'] = df['images'].fillna('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQxmLd-lKZathn7_IQch_8EtHCMJ7HxOUGaS5L02rc8_A&s=10')

# %% [markdown]
# ##### Show Before & After Handle missing values

# %%
print("\n--- Missing Values Remaining ---")
print(df[['what_customers_said', 'seller_name']].isnull().sum())
# Out:
# --- Missing Values Remaining ---
# what_customers_said    0
# seller_name            0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(14, 5))

# 1. Boxplot for Prices (Check for expensive outliers)
plt.subplot(1, 2, 1)
sns.boxplot(x=df['final_price_usd'], color='skyblue')
plt.title('Distribution of Final Prices (USD) - Outlier Check')
plt.xlabel('Price in USD')

# 2. Boxplot for Ratings (Check for odd ratings)
plt.subplot(1, 2, 2)
sns.boxplot(x=df['rating'], color='lightgreen')
plt.title('Distribution of Ratings - Outlier Check')
plt.xlabel('Rating (0 to 5)')

plt.tight_layout()

# Save the plot so I can view it!
plot_path = "../data/outliers_check.png"
plt.savefig(plot_path, dpi=300)
plt.show()

print(f"📊 Plot saved to {plot_path}")
# Out:
# 📊 Plot saved to ../data/outliers_check.png

# %% [markdown]
# > ## Notes :
# - **Prices:** Outliers up to $200+ are valid and represent premium products, so we will keep them.
# - **Ratings:** Low ratings (0–2) are also valid and useful for helping the chatbot avoid recommending poor products.

# %% [markdown]
# ---

# %% [markdown]
# ### Defect 3: Clean Text Columns (HTML tags & extra spaces)

# %% [markdown]
# - The text columns (`title`, `product_description`, `what_customers_said`, `product_specifications`) might contain raw HTML tags or excessive whitespaces.
# - We need to strip these to ensure clean text for the RAG search and LLM models.

# %%
import re

def clean_text(text):
    text = str(text)
    text = re.sub(r'<[^>]+>', '', text)             # Remove HTML tags (like <br>, <b>)
    text = ' '.join(text.split())                # Remove extra spaces and newlines
    return text

text_columns = ['title', 'product_description', 'what_customers_said', 'product_specifications']

print("--- Text Cleaning Check ---")
print("Before:", df[text_columns].iloc[46])

# ================== Apply Cleaning ==================

for col in text_columns:
    df[col] = df[col].apply(clean_text)

print("\nAfter: ", df[text_columns].iloc[46])
# Out:
# --- Text Cleaning Check ---
# Before: title                                                            Chromozome
# product_description       Men Pack of 4 Premium Pure Cotton Mini Briefs ...
# what_customers_said       [{"percentage":"40","value_name":"Fit, A Littl...
# product_specifications    [{"specification_name":"Assorted","specificati...
# Name: 46, dtype: object
# After:  title                                                            Chromozome
# product_description       Men Pack of 4 Premium Pure Cotton Mini Briefs ...
# what_customers_said       [{"percentage":"40","value_name":"Fit, A Littl...
# product_specifications    [{"specification_name":"Assorted","specificati...
# Name: 46, dtype: object

# %% [markdown]
# ### Drop original prices & Export Clean Data
# - Now that we have `final_price_usd` and `initial_price_usd`, we can drop the messy string columns.
# - Finally, save the clean dataset to `data/products_clean.csv`.

# %%
# Drop the old uncleaned price columns
df = df.drop(columns=['initial_price', 'final_price'])

# Save to CSV
clean_csv_path = "../data/products_clean.csv"
df.to_csv(clean_csv_path, index=False)

print(f"✅ Clean data saved successfully to {clean_csv_path}")
print("Final Shape:", df.shape)
# Out:
# ✅ Clean data saved successfully to ../data/products_clean.csv
# Final Shape: (1000, 24)
